# %%
import os
import pandas as pd
import yaml

from utils.training_utils import get_features_attribute

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
features_config = yaml.safe_load(open(os.path.join('..', 'src', 'config', 'feature_config.yaml'), "r"))

# %%
df_train_clf = pd.read_parquet(os.path.join('..', 'data', 'train_test', 'train_promotion_clf.parquet'))

print(df_train_clf.shape)
df_train_clf.head()
# Out:
# (217312, 43)
#               id                                              title  \
# 0   MLV734418019  Repuesto De 10 Piedras Pedernal Para Encendedo...
# 1   MPE603710167  Stud 100 Spray Retardante Prolongador - Sexsho...
# 2   MBO572244016  Hermosa Casa En Alquiler 5to Anillo Doble La G...
# 3   MEC595296890          Uhu Power Pegamento De Contacto Pomo 50ml
# 4  MLA1421037335        Vasos Plasticos Milkshake X 20 U - Lollipop
#
#        condition                  thumbnail_id catalog_product_id  \
# 0            new  725159-MLV53437450242_012023               None
# 1            new  664673-MPE48056676928_102021               None
# 2  not_specified  675746-MBO81868955195_012025               None
# 3            new  825354-MLU73068602833_112023        MEC28392452
# 4            new  708978-MLA75732794941_042024               None
#
#   listing_type_id                                          permalink  \
# 0    gold_special  https://articulo.mercadolibre.com.ve/MLV-73441...
# ...

# %%
df_train_reg = pd.read_parquet(os.path.join('..', 'data', 'train_test', 'train_promotion_reg.parquet'))

print(df_train_reg.shape)
df_train_reg.head()
# Out:
# (49407, 44)
#               id                                              title condition  \
# 0   MLU479851199  Pulseras Esclavas Para Parejas His Queen Her King       new
# 1   MLU653450002  Silla De Escritorio Meetion Chr15 Mt-chr15 Gam...       new
# 2  MCO2209369810  Cinta Ancha Adhesiva Transparent X 6 Rollos Em...       new
# 3  MCO1418614159  Escalera Plegable 2 Pasos Acero Capacidad 150k...       new
# 4  MLB4825917896  Cd Marilyn Manson - The Pale Amperor Versão Do...       new
#
#                    thumbnail_id catalog_product_id listing_type_id  \
# 0  702091-MLU46286789444_062021               None    gold_special
# 1  950198-MLA45372964153_032021        MLU17434815    gold_special
# 2  770242-MLU78453358709_082024        MCO32624832        gold_pro
# 3  610806-MCO76090689635_042024               None        gold_pro
# 4  807183-MLU77443567525_072024        MLB22507487        gold_pro
#
#                                            permalink buying_mode site_id  \
# ...
