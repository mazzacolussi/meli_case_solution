# %%
import os
import pandas as pd
import yaml
import requests
from concurrent.futures import ThreadPoolExecutor

from utils.training_utils import get_features_attribute

import warnings
warnings.filterwarnings('ignore')

# %%
country_info = yaml.safe_load(open(os.path.join('..', 'src', 'config', 'country_infos.yaml'), "r"))
features_config = yaml.safe_load(open(os.path.join('..', 'src', 'config', 'feature_config.yaml'), "r"))
features_struct = get_features_attribute(features_config, attribute='struct')

# %%
cats = requests.get('https://api.mercadolibre.com/sites/MLA/categories')
cats.json()
# Out:
# [{'id': 'MLA5725', 'name': 'Accesorios para Vehículos'},
#  {'id': 'MLA1512', 'name': 'Agro'},
#  {'id': 'MLA1403', 'name': 'Alimentos y Bebidas'},
#  {'id': 'MLA1071', 'name': 'Animales y Mascotas'},
#  {'id': 'MLA1367', 'name': 'Antigüedades y Colecciones'},
#  {'id': 'MLA1368', 'name': 'Arte, Librería y Mercería'},
#  {'id': 'MLA1743', 'name': 'Autos, Motos y Otros'},
#  {'id': 'MLA1384', 'name': 'Bebés'},
#  {'id': 'MLA1246', 'name': 'Belleza y Cuidado Personal'},
#  {'id': 'MLA1039', 'name': 'Cámaras y Accesorios'},
#  {'id': 'MLA1051', 'name': 'Celulares y Teléfonos'},
#  {'id': 'MLA1648', 'name': 'Computación'},
#  {'id': 'MLA1144', 'name': 'Consolas y Videojuegos'},
#  {'id': 'MLA1500', 'name': 'Construcción'},
#  {'id': 'MLA1276', 'name': 'Deportes y Fitness'},
#  {'id': 'MLA5726', 'name': 'Electrodomésticos y Aires Ac.'},
#  {'id': 'MLA1000', 'name': 'Electrónica, Audio y Video'},
#  {'id': 'MLA2547', 'name': 'Entradas para Eventos'},
#  {'id': 'MLA407134', 'name': 'Herramientas'},
#  {'id': 'MLA1574', 'name': 'Hogar, Muebles y Jardín'},
#  {'id': 'MLA1499', 'name': 'Industrias y Oficinas'},
#  {'id': 'MLA1459', 'name': 'Inmuebles'},
#  {'id': 'MLA1182', 'name': 'Instrumentos Musicales'},
#  {'id': 'MLA3937', 'name': 'Joyas y Relojes'},
#  {'id': 'MLA1132', 'name': 'Juegos y Juguetes'},
#  {'id': 'MLA3025', 'name': 'Libros, Revistas y Comics'},
#  {'id': 'MLA1168', 'name': 'Música, Películas y Series'},
#  {'id': 'MLA1430', 'name': 'Ropa y Accesorios'},
#  {'id': 'MLA409431', 'name': 'Salud y Equipamiento Médico'},
#  {'id': 'MLA1540', 'name': 'Servicios'},
#  {'id': 'MLA9304', 'name': 'Souvenirs, Cotillón y Fiestas'},
#  {'id': 'MLA1953', 'name': 'Otras categorías'}]

# %%
cat_id = 'MLA1000'
offset = 50
url = f'https://api.mercadolibre.com/sites/MLA/search?category={cat_id}&offset={offset}'
request = requests.get(url)
items = request.json()
items
# Out:
# {'site_id': 'MLA',
#  'country_default_time_zone': 'GMT-03:00',
#  'paging': {'total': 605812,
#   'primary_results': 1000,
#   'offset': 50,
#   'limit': 50},
#  'results': [{'id': 'MLA1426502877',
#    'title': 'Auriculares Inalambricos A8s Alpina Touch 25 Hs Bateria',
#    'condition': 'new',
#    'thumbnail_id': '943298-MLU78043800626_082024',
#    'catalog_product_id': 'MLA23199380',
#    'listing_type_id': 'gold_special',
#    'sanitized_title': '',
#    'permalink': 'https://www.mercadolibre.com.ar/auriculares-inalambricos-a8s-alpina-touch-25-hs-bateria/p/MLA23199380#wid=MLA1426502877&sid=unknown',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA3697',
#    'domain_id': 'MLA-HEADPHONES',
#    'thumbnail': 'http://http2.mlstatic.com/D_943298-MLU78043800626_082024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 1,
#    'price': 7492,
#    'original_price': 9970,
#    'sale_price': {'price_id': '',
#     'amount': 7492,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': '2025-01-13T03:00:00Z',
#      'end_time': '2025-02-01T02:59:00Z'},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': 9970,
#     'type': 'promotion',
#     'metadata': {'discount_meli_amount': 499,
#      'experiment_id': 'cm_med_uplift_P-MLA14525518',
#      'promotion_id': 'OFFER-MLA1426502877-10251830986',
#      'variation': '67058',
#      'campaign_discount_percentage': 24.85,
#      'campaign_end_date': '2025-02-01T02:59:00Z',
#      'campaign_id': 'P-MLA14525518',
#      'funding_mode': 'coupon',
#      'order_item_price': 7991,
#      'promotion_type': 'marketplace_campaign'}},
#    'available_quantity': 250,
#    'official_store_id': 2541,
#    'official_store_name': 'Alpina',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'MLA-CHG-threshold-nov-23', 'self_service_in'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-08-24T14:26:33.000Z',
#    'seller': {'id': 685241555, 'nickname': 'ALPINA ARG'},
#    'address': {'state_id': 'AR-C',
#     'state_name': 'Capital Federal',
#     'city_id': 'TUxBQk1BVDMwMDJa',
#     'city_name': 'Mataderos'},
#    'attributes': [{'id': 'ALPHANUMERIC_MODEL',
#      'name': 'Modelo alfanumérico',
#      'value_id': '19035495',
#      'value_name': 'A8S',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '19035495',
#        'name': 'A8S',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '2455250',
#      'value_name': 'Alpina',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2455250',
#        'name': 'Alpina',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'COLOR',
#      'name': 'Color',
#      'value_id': '52049',
#      'value_name': 'Negro',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '52049', 'name': 'Negro', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '0763571691144,0763571691137',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '0763571691144',
#        'struct': None,
#        'source': 4333789534002961},
#       {'id': None,
#        'name': '0763571691137',
#        'struct': None,
#        'source': 385122562515662}],
#      'source': 4333789534002961,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'source': 6808261514773724,
#      'value_type': 'list'},
#     {'id': 'MAIN_COLOR',
#      'name': 'Color principal',
#      'value_id': '2450295',
#      'value_name': 'Negro',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2450295',
#        'name': 'Negro',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '8164941',
#      'value_name': 'A8s',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '8164941', 'name': 'A8s', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '7.8 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 7.8, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '7.8 cm',
#        'struct': {'number': 7.8, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '60 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 60, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '60 g',
#        'struct': {'unit': 'g', 'number': 60},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 1683.95,
#     'rate': 34.86,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotion_decorations': None,
#    'promotions': None,
#    'inventory_id': 'FYBV04246'},
#   {'id': 'MLA1389037987',
#    'title': 'Auriculares Inalámbricos Xiaomi Redmi Buds 4 Lite In-ear Negro',
#    'condition': 'new',
#    'thumbnail_id': '951543-MLA80564113806_112024',
#    'catalog_product_id': 'MLA22609606',
#    'listing_type_id': 'gold_special',
#    'sanitized_title': '',
#    'permalink': 'https://www.mercadolibre.com.ar/auriculares-inalambricos-xiaomi-redmi-buds-4-lite-in-ear-negro/p/MLA22609606#wid=MLA1389037987&sid=unknown',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA3697',
#    'domain_id': 'MLA-HEADPHONES',
#    'thumbnail': 'http://http2.mlstatic.com/D_951543-MLA80564113806_112024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 2,
#    'price': 24999,
#    'original_price': 27999,
#    'sale_price': {'price_id': '',
#     'amount': 24999,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': '2025-01-10T03:00:00Z',
#      'end_time': '2025-01-20T02:59:00Z'},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': 27999,
#     'type': 'promotion',
#     'metadata': {'promotion_type': 'marketplace_campaign',
#      'variation': '67000',
#      'campaign_id': 'P-MLA14541108',
#      'discount_meli_amount': 1000,
#      'experiment_id': 'cm_med_uplift_P-MLA14541108',
#      'funding_mode': 'coupon',
#      'promotion_id': 'OFFER-MLA1389037987-10250489881',
#      'campaign_discount_percentage': 10.71,
#      'campaign_end_date': '2025-01-20T02:59:00Z',
#      'order_item_price': 25999}},
#    'available_quantity': 250,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_in'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2043-09-15T04:00:00.000Z',
#    'seller': {'id': 262582139, 'nickname': 'IVMACO'},
#    'address': {'state_id': 'AR-C',
#     'state_name': 'Capital Federal',
#     'city_id': 'TUxBQkJBUjM0MDha',
#     'city_name': 'Barracas'},
#    'attributes': [{'id': 'ALPHANUMERIC_MODEL',
#      'name': 'Modelo alfanumérico',
#      'value_id': '18213543',
#      'value_name': 'BHR7118GL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18213543',
#        'name': 'BHR7118GL',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '59387',
#      'value_name': 'Xiaomi',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '59387',
#        'name': 'Xiaomi',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'COLOR',
#      'name': 'Color',
#      'value_id': '52049',
#      'value_name': 'Negro',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '52049', 'name': 'Negro', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '6941812721032',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '6941812721032',
#        'struct': None,
#        'source': 385122562515662}],
#      'source': 2860837171021627,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '199791',
#      'value_name': 'Redmi',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '199791',
#        'name': 'Redmi',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'string'},
#     {'id': 'MAIN_COLOR',
#      'name': 'Color principal',
#      'value_id': '2450295',
#      'value_name': 'Negro',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2450295',
#        'name': 'Negro',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '18213544',
#      'value_name': 'Buds 4 lite',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18213544',
#        'name': 'Buds 4 lite',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '10.2 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 10.2, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '10.2 cm',
#        'struct': {'unit': 'cm', 'number': 10.2},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '80 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 80, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '80 g',
#        'struct': {'number': 80, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 5618.94,
#     'rate': 34.86,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotion_decorations': None,
#    'promotions': None,
#    'inventory_id': 'JHXN23112'},
#   {'id': 'MLA1985406590',
#    'title': 'Convertidor Roku Premiere 4k Hdr Streaming + Control Remoto Color Negro',
#    'condition': 'new',
#    'thumbnail_id': '932140-MLU72943691240_112023',
#    'catalog_product_id': 'MLA28278924',
#    'listing_type_id': 'gold_special',
#    'sanitized_title': '',
#    'permalink': 'https://www.mercadolibre.com.ar/convertidor-roku-premiere-4k-hdr-streaming-control-remoto-color-negro/p/MLA28278924#wid=MLA1985406590&sid=unknown',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA352001',
#    'domain_id': 'MLA-STREAMING_MEDIA_DEVICES',
#    'thumbnail': 'http://http2.mlstatic.com/D_932140-MLU72943691240_112023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 3,
#    'price': 55197,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 55197,
#     'conditions': {'eligible': True,
#      'context_restrictions': [],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 50,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-12-21T17:43:02.573Z',
#    'seller': {'id': 315567563, 'nickname': 'YAYATIENDAWEB'},
#    'address': {'state_id': 'AR-S',
#     'state_name': 'Santa Fe',
#     'city_id': 'TUxBQ1JPUzg1Yjg3',
#     'city_name': 'Rosario'},
#    'attributes': [{'id': 'ALPHANUMERIC_MODEL',
#      'name': 'Modelo alfanumérico',
#      'value_id': '26387709',
#      'value_name': '3920RW-SW',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '26387709',
#        'name': '3920RW-SW',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '168521',
#      'value_name': 'Roku',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '168521', 'name': 'Roku', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'COLOR',
#      'name': 'Color',
#      'value_id': '52049',
#      'value_name': 'Negro',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '52049', 'name': 'Negro', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '829610007175',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '829610007175',
#        'struct': None,
#        'source': 385122562515662}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'LENGTH',
#      'name': 'Largo',
#      'value_id': '10260151',
#      'value_name': '3.6 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 3.6, 'unit': 'cm'},
#      'values': [{'id': '10260151',
#        'name': '3.6 cm',
#        'struct': {'number': 3.6, 'unit': 'cm'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '17583043',
#      'value_name': '3920',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '17583043',
#        'name': '3920',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MAIN_COLOR',
#      'name': 'Color principal',
#      'value_id': '2450295',
#      'value_name': 'Negro',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2450295',
#        'name': 'Negro',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '26387710',
#      'value_name': '4K/HDR',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '26387710',
#        'name': '4K/HDR',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '16.6 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 16.6, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '16.6 cm',
#        'struct': {'unit': 'cm', 'number': 16.6},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '260 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 260, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '260 g',
#        'struct': {'number': 260, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '5991223',
#      'value_name': '1 kg',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 1, 'unit': 'kg'},
#      'values': [{'id': '5991223',
#        'name': '1 kg',
#        'struct': {'number': 1, 'unit': 'kg'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 12406.45,
#     'rate': 34.86,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotion_decorations': None,
#    'promotions': None,
#    'inventory_id': 'FBOU60646'},
#   {'id': 'MLA1679550160',
#    'title': 'Radio Portatil Retro Vintage Spica Sp-590 Am/fm Recargable Color Bordó',
#    'condition': 'new',
#    'thumbnail_id': '708707-MLU74678301787_022024',
#    'catalog_product_id': 'MLA34018049',
#    'listing_type_id': 'gold_special',
#    'sanitized_title': '',
#    'permalink': 'https://www.mercadolibre.com.ar/radio-portatil-retro-vintage-spica-sp-590-amfm-recargable-color-bordo/p/MLA34018049#wid=MLA1679550160&sid=unknown',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA2854',
#    'domain_id': 'MLA-AM_FM_SW_RADIOS',
#    'thumbnail': 'http://http2.mlstatic.com/D_708707-MLU74678301787_022024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 4,
#    'price': 26399,
#    'original_price': 79999,
#    'sale_price': {'price_id': '',
#     'amount': 26399,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': '2024-12-26T03:00:00Z',
#      'end_time': '2025-01-26T02:59:59Z'},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': 79999,
#     'type': 'promotion',
#     'metadata': {'promotion_id': 'OFFER-MLA1679550160-10240553077',
#      'promotion_type': 'custom'}},
#    'available_quantity': 1,
#    'official_store_id': 2839,
#    'official_store_name': 'LIBERCAM',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'self_service_out', 'self_service_available'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-02-18T04:00:00.000Z',
#    'seller': {'id': 13647702, 'nickname': 'LIBERCAM'},
#    'address': {'state_id': 'AR-C',
#     'state_name': 'Capital Federal',
#     'city_id': 'TUxBQkJPRTQ0OTRa',
#     'city_name': 'Boedo'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '2510628',
#      'value_name': 'Spica',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2510628',
#        'name': 'Spica',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'COLOR',
#      'name': 'Color',
#      'value_id': '51998',
#      'value_name': 'Bordó',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '51998', 'name': 'Bordó', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'DETAILED_MODEL',
#      'name': 'Modelo detallado',
#      'value_id': '34245919',
#      'value_name': 'SP-590BO',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '34245919',
#        'name': 'SP-590BO',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '7798383037708',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '7798383037708',
#        'struct': None,
#        'source': 385122562515662}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '34245918',
#      'value_name': 'sp-590',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '34245918',
#        'name': 'sp-590',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '13 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 13, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '13 cm',
#        'struct': {'unit': 'cm', 'number': 13},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '220 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 220, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '220 g',
#        'struct': {'number': 220, 'unit': 'g'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '18321370',
#      'value_name': '138 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 138, 'unit': 'g'},
#      'values': [{'id': '18321370',
#        'name': '138 g',
#        'struct': {'number': 138, 'unit': 'g'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 5933.62,
#     'rate': 34.86,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotion_decorations': None,
#    'promotions': None,
#    'inventory_id': 'GFQR15049'},
#   {'id': 'MLA1293484430',
#    'title': 'Auricular In-ear Gamer Inalámbrico  Xg-8 Xg-8 Negro Con Luz Led',
#    'condition': 'new',
#    'thumbnail_id': '904509-MLU77408155196_072024',
#    'catalog_product_id': 'MLA19569064',
#    'listing_type_id': 'gold_special',
#    'sanitized_title': '',
#    'permalink': 'https://www.mercadolibre.com.ar/auricular-in-ear-gamer-inalambrico-xg-8-xg-8-negro-con-luz-led/p/MLA19569064#wid=MLA1293484430&sid=unknown',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA3697',
#    'domain_id': 'MLA-HEADPHONES',
#    'thumbnail': 'http://http2.mlstatic.com/D_904509-MLU77408155196_072024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 5,
#    'price': 9173,
#    'original_price': 11900,
#    'sale_price': {'price_id': '',
#     'amount': 9173,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': '2025-01-06T03:00:00Z',
#      'end_time': '2025-02-01T02:59:00Z'},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': 11900,
#     'type': 'promotion',
#     'metadata': {'experiment_id': 'cm_med_uplift_P-MLA14525518',
#      'funding_mode': 'coupon',
#      'order_item_price': 9555,
#      'promotion_id': 'OFFER-MLA1293484430-10247761081',
#      'campaign_id': 'P-MLA14525518',
#      'campaign_end_date': '2025-02-01T02:59:00Z',
#      'discount_meli_amount': 382,
#      'promotion_type': 'marketplace_campaign',
#      'variation': '67058',
#      'campaign_discount_percentage': 22.92}},
#    'available_quantity': 150,
#    'official_store_id': 123224,
#    'official_store_name': 'Sti digital',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'self_service_out', 'self_service_available'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-05-11T16:38:22.000Z',
#    'seller': {'id': 19876329, 'nickname': 'STIDIGITAL.'},
#    'address': {'state_id': 'AR-C',
#     'state_name': 'Capital Federal',
#     'city_id': None,
#     'city_name': 'mataderos'},
#    'attributes': [{'id': 'ALPHANUMERIC_MODEL',
#      'name': 'Modelo alfanumérico',
#      'value_id': '16547536',
#      'value_name': 'XG-8',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '16547536',
#        'name': 'XG-8',
#        'struct': None,
#        'source': 6808261514773724}],
#      'source': 6808261514773724,
#      'value_type': 'string'},
#     {'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '276243',
#      'value_name': 'Genérica',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '276243',
#        'name': 'Genérica',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'COLOR',
#      'name': 'Color',
#      'value_id': '52049',
#      'value_name': 'Negro',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '52049', 'name': 'Negro', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'DETAILED_MODEL',
#      'name': 'Modelo detallado',
#      'value_id': '19149801',
#      'value_name': 'in ear',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '19149801',
#        'name': 'in ear',
#        'struct': None,
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'source': 6808261514773724,
#      'value_type': 'list'},
#     {'id': 'MAIN_COLOR',
#      'name': 'Color principal',
#      'value_id': '2450295',
#      'value_name': 'Negro',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2450295',
#        'name': 'Negro',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '9698656',
#      'value_name': 'XG-8',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '9698656',
#        'name': 'XG-8',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '10.8 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 10.8, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '10.8 cm',
#        'struct': {'number': 10.8, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '60 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 60, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '60 g',
#        'struct': {'number': 60, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 2061.78,
#     'rate': 34.86,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotion_decorations': None,
#    'promotions': None,
#    'inventory_id': 'DEXY77013'},
#   {'id': 'MLA1398643417',
#    'title': 'Smart Tv Samsung 55 Cristal Uhd 4k Cu7000',
#    'condition': 'new',
#    'thumbnail_id': '787255-MLU75979268213_042024',
#    'catalog_product_id': 'MLA28297083',
#    'listing_type_id': 'gold_pro',
#    'sanitized_title': '',
#    'permalink': 'https://www.mercadolibre.com.ar/smart-tv-samsung-55-cristal-uhd-4k-cu7000/p/MLA28297083#wid=MLA1398643417&sid=unknown',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA1002',
#    'domain_id': 'MLA-TELEVISIONS',
#    'thumbnail': 'http://http2.mlstatic.com/D_787255-MLU75979268213_042024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 6,
#    'price': 791999.1,
#    'original_price': 879999,
#    'sale_price': {'price_id': '',
#     'amount': 791999.1,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': '2025-01-14T03:00:00Z',
#      'end_time': '2025-01-20T02:59:00Z'},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': 879999,
#     'type': 'promotion',
#     'metadata': {'promotion_type': 'campaign',
#      'campaign_id': 'MLA55444',
#      'promotion_id': 'OFFER-MLA1398643417-10251509204'}},
#    'available_quantity': 200,
#    'official_store_id': 1938,
#    'official_store_name': 'Mercado Libre',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-08-28T13:00:51.000Z',
#    'seller': {'id': 608846165, 'nickname': 'MERCADOLIBRE ELECTRONICA_AR'},
#    'address': {'state_id': 'AR-B',
#     'state_name': 'Buenos Aires',
#     'city_id': None,
#     'city_name': 'Villa Celina'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '206',
#      'value_name': 'Samsung',
#      'attribute_group_id': 'MAIN',
#      'attribute_group_name': 'Principales',
#      'value_struct': None,
#      'values': [{'id': '206', 'name': 'Samsung', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '26414413',
#      'value_name': 'UN55CU7000',
#      'attribute_group_id': 'MAIN',
#      'attribute_group_name': 'Principales',
#      'value_struct': None,
#      'values': [{'id': '26414413',
#        'name': 'UN55CU7000',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ALPHANUMERIC_MODEL',
#      'name': 'Modelo alfanumérico',
#      'value_id': '26414415',
#      'value_name': 'UN55CU7000GCZB',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '26414415',
#        'name': 'UN55CU7000GCZB',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'COLOR',
#      'name': 'Color',
#      'value_id': '52049',
#      'value_name': 'Negro',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '52049', 'name': 'Negro', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '8806094900552',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '8806094900552',
#        'struct': None,
#        'source': 385122562515662}],
#      'source': 8748668969142,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': None,
#      'value_name': 'n/a',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'n/a',
#        'struct': None,
#        'source': 8748668969142}],
#      'source': 8748668969142,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '138 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 138, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '138 cm',
#        'struct': {'number': 138, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '17240 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 17240, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '17240 g',
#        'struct': {'number': 17240, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '7195928',
#      'value_name': '13.1 kg',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 13.1, 'unit': 'kg'},
#      'values': [{'id': '7195928',
#        'name': '13.1 kg',
#        'struct': {'number': 13.1, 'unit': 'kg'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 12,
#     'amount': 65999.92,
#     'rate': 0,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotion_decorations': None,
#    'promotions': None,
#    'inventory_id': 'GNCM84914'},
#   {'id': 'MLA1439938373',
#    'title': 'Auriculares In-ear Inalámbricos Jbl  Wave Buds Blanco',
#    'condition': 'new',
#    'thumbnail_id': '788775-MLU75050712832_032024',
#    'catalog_product_id': 'MLA24559022',
#    'listing_type_id': 'gold_special',
#    'sanitized_title': '',
#    'permalink': 'https://www.mercadolibre.com.ar/auriculares-in-ear-inalambricos-jbl-wave-buds-blanco/p/MLA24559022#wid=MLA1439938373&sid=unknown',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA3697',
#    'domain_id': 'MLA-HEADPHONES',
#    'thumbnail': 'http://http2.mlstatic.com/D_788775-MLU75050712832_032024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 7,
#    'price': 81683,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 81683,
#     'conditions': {'eligible': True,
#      'context_restrictions': [],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment',
#      'self_service_out',
#      'mandatory_free_shipping',
#      'self_service_available'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-07-25T04:00:00.000Z',
#    'seller': {'id': 148613909, 'nickname': 'VYSECOMAR'},
#    'address': {'state_id': 'AR-X',
#     'state_name': 'Córdoba',
#     'city_id': 'TUxBQ0NBUGNiZGQx',
#     'city_name': 'Córdoba'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '17265',
#      'value_name': 'JBL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '17265', 'name': 'JBL', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'CABLE_LENGTH',
#      'name': 'Largo del cable',
#      'value_id': '124833',
#      'value_name': '1.2 m',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 1.2, 'unit': 'm'},
#      'values': [{'id': '124833',
#        'name': '1.2 m',
#        'struct': {'unit': 'm', 'number': 1.2},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'COLOR',
#      'name': 'Color',
#      'value_id': '52055',
#      'value_name': 'Blanco',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '52055',
#        'name': 'Blanco',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'DETAILED_MODEL',
#      'name': 'Modelo detallado',
#      'value_id': '18612355',
#      'value_name': 'JBLWBUDSWHT',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18612355',
#        'name': 'JBLWBUDSWHT',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '43700',
#      'value_name': 'Wave',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '43700', 'name': 'Wave', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MAIN_COLOR',
#      'name': 'Color principal',
#      'value_id': '2450308',
#      'value_name': 'Blanco',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2450308',
#        'name': 'Blanco',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '18612339',
#      'value_name': 'Wave Buds',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18612339',
#        'name': 'Wave Buds',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '13.8 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 13.8, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '13.8 cm',
#        'struct': {'number': 13.8, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '120 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 120, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '120 g',
#        'struct': {'number': 120, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 18359.62,
#     'rate': 34.86,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotion_decorations': None,
#    'promotions': None,
#    'inventory_id': 'SJFI85720'},
#   {'id': 'MLA1847407054',
#    'title': 'Parlante Xiaomi Mi Portable Bluetooth Speaker Gray Portatil Color Negro',
#    'condition': 'new',
#    'thumbnail_id': '797226-MLU72755782502_112023',
#    'catalog_product_id': 'MLA24541161',
#    'listing_type_id': 'gold_special',
#    'sanitized_title': '',
#    'permalink': 'https://www.mercadolibre.com.ar/parlante-xiaomi-mi-portable-bluetooth-speaker-gray-portatil-color-negro/p/MLA24541161#wid=MLA1847407054&sid=unknown',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA8618',
#    'domain_id': 'MLA-SPEAKERS',
#    'thumbnail': 'http://http2.mlstatic.com/D_797226-MLU72755782502_112023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 8,
#    'price': 45193,
#    'original_price': 67999,
#    'sale_price': {'price_id': '',
#     'amount': 45193,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': '2025-01-01T03:00:00Z',
#      'end_time': '2025-01-31T02:59:00Z'},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': 67999,
#     'type': 'promotion',
#     'metadata': {'campaign_end_date': '2025-01-31T02:59:00Z',
#      'order_item_price': 45928,
#      'promotion_id': 'OFFER-MLA1847407054-10244990994',
#      'variation': '67000',
#      'campaign_discount_percentage': 33.54,
#      'campaign_id': 'P-MLA14541108',
#      'discount_meli_amount': 735,
#      'experiment_id': 'cm_med_uplift_P-MLA14541108',
#      'funding_mode': 'coupon',
#      'promotion_type': 'marketplace_campaign'}},
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-12-12T17:28:52.649Z',
#    'seller': {'id': 448487402, 'nickname': 'OHPIC'},
#    'address': {'state_id': 'AR-C',
#     'state_name': 'Capital Federal',
#     'city_id': 'TUxBQk7a0TcwOTRa',
#     'city_name': 'Núñez'},
#    'attributes': [{'id': 'ALPHANUMERIC_MODEL',
#      'name': 'Modelo alfanumérico',
#      'value_id': '10472613',
#      'value_name': 'MDZ-26-DB',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '10472613',
#        'name': 'MDZ-26-DB',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '59387',
#      'value_name': 'Xiaomi',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id':
#     {'id': '19971510', 'name': '1Mii', 'results': 119},
#     {'id': '15555', 'name': 'Luxell', 'results': 119},
#     {'id': '3762995', 'name': 'Nippon', 'results': 119},
#     {'id': '497897', 'name': 'Alctron', 'results': 119},
#     {'id': '36649163', 'name': 'Toptrend', 'results': 119},
#     {'id': '9509', 'name': 'Numark', 'results': 119},
#     {'id': '977212', 'name': 'Crosley', 'results': 119},
#     {'id': '20451048', 'name': 'Aequipe', 'results': 119},
#     {'id': '4067656', 'name': 'Hidizs', 'results': 119},
#     {'id': '26411', 'name': 'Ampro', 'results': 119},
#     {'id': '6696844', 'name': 'LCT', 'results': 119},
#     {'id': '11221423', 'name': 'Canboc', 'results': 119},
#     {'id': '20410301', 'name': 'Goso', 'results': 119},
#     {'id': '47354', 'name': 'Corsair', 'results': 119},
#     {'id': '13919783', 'name': 'NKO', 'results': 119},
#     {'id': '18767154', 'name': 'NetBit', 'results': 119},
#     {'id': '14750377', 'name': '1More', 'results': 119},
#     {'id': '16495181', 'name': 'Richtek', 'results': 119},
#     {'id': '59391', 'name': 'VAC', 'results': 119},
#     {'id': '43822835', 'name': 'MUSYCOM', 'results': 119},
#     {'id': '39874620', 'name': 'New Akira', 'results': 119},
#     {'id': '2732569', 'name': 'Martin', 'results': 119},
#     {'id': '37103056', 'name': 'Select Lighting', 'results': 119},
#     {'id': '36754458', 'name': 'Wjjitan', 'results': 119},
#     {'id': '18373843', 'name': 'Elemax', 'results': 119},
#     {'id': '16588580', 'name': 'Stagelab', 'results': 119},
#     {'id': '31926225', 'name': 'Lonpoo', 'results': 119},
#     {'id': '33309956', 'name': 'Rounkin', 'results': 119},
#     {'id': '1131532', 'name': 'Time', 'results': 119},
#     {'id': '25476101', 'name': 'Alpha y Omega', 'results': 119},
#     {'id': '25476105', 'name': 'Controles Pm', 'results': 119},
#     {'id': '35265035', 'name': 'Suuntok', 'results': 119},
#     {'id': '97675', 'name': 'Bluedio', 'results': 119},
#     {'id': '33090955', 'name': 'Aoicrie', 'results': 119},
#     {'id': '28512476', 'name': 'Warrky', 'results': 119},
#     {'id': '119442', 'name': 'Eveready', 'results': 119},
#     {'id': '17073180', 'name': 'Justjamz', 'results': 119},
#     {'id': '26519932', 'name': 'Komison', 'results': 119},
#     {'id': '11854809', 'name': 'Winbond', 'results': 119},
#     {'id': '25882761', 'name': 'Keewonda', 'results': 119},
#     {'id': '26394821', 'name': 'Nanosecond', 'results': 119},
#     {'id': '25476115', 'name': 'Sanken', 'results': 119},
#     {'id': '23892302', 'name': 'Marboo', 'results': 119},
#     {'id': '4060193', 'name': 'Elgato', 'results': 119},
#     {'id': '12103730', 'name': 'TEC', 'results': 119},
#     {'id': '411191', 'name': 'Awd', 'results': 119},
#     {'id': '43795405', 'name': 'Zettler', 'results': 119},
#     {'id': '2442495', 'name': 'Warm Audio', 'results': 119},
#     {'id': '17159679', 'name': 'Proster', 'results': 119},
#     {'id': '27116046', 'name': 'Rlsoco', 'results': 119},
#     {'id': '28585603', 'name': 'Switchflux', 'results': 119},
#     {'id': '10273', 'name': 'Encore', 'results': 119},
#     {'id': '3155502', 'name': 'On-Stage', 'results': 119},
#     {'id': '4857309', 'name': 'DB', 'results': 119},
#     ...]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condición',
#    'type': 'STRING',
#    'values': [{'id': '2230284', 'name': 'Nuevo', 'results': 476833},
#     {'id': '2230581', 'name': 'Usado', 'results': 123998},
#     {'id': '2230582', 'name': 'Reacondicionado', 'results': 952}]},
#   {'id': 'SHIPPING_ORIGIN',
#    'name': 'Tipo de compra',
#    'type': 'STRING',
#    'values': [{'id': '10215068', 'name': 'Local', 'results': 546567},
#     {'id': '10215069', 'name': 'Internacional', 'results': 55573}]},
#   {'id': 'category',
#    'name': 'Categorías',
#    'type': 'text',
#    'values': [{'id': 'MLA409810', 'name': 'Audio', 'results': 184777},
#     {'id': 'MLA1002', 'name': 'Televisores', 'results': 8309},
#     {'id': 'MLA11830', 'name': 'Componentes Electrónicos', 'results': 197274},
#     {'id': 'MLA322074', 'name': 'Repuestos para TV', 'results': 85400},
#     {'id': 'MLA5054', 'name': 'Cables', 'results': 39285},
#     {'id': 'MLA4641', 'name': 'Pilas y Cargadores', 'results': 22943},
#     {'id': 'MLA4632', 'name': 'Controles Remotos', 'results': 15739},
#     {'id': 'MLA3690',
#      'name': 'Accesorios para Audio y Video',
#      'results': 13299},
#     {'id': 'MLA431414', 'name': 'Accesorios para TV', 'results': 11959},
#     {'id': 'MLA4800', 'name': 'Proyectores y Pantallas', 'results': 8297},
#     {'id': 'MLA352294', 'name': 'Drones y Accesorios', 'results': 7808},
#     {'id': 'MLA1015', 'name': 'Video', 'results': 5246},
#     {'id': 'MLA352001', 'name': 'Media Streaming', 'results': 2322},
#     {'id': 'MLA58775', 'name': 'Fundas y Bolsos', 'results': 1464},
#     {'id': 'MLA1070', 'name': 'Otros', 'results': 1586}]}],
#  'pdp_tracking': {'group': False,
#   'product_info': [{'id': 'MLA23199380', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA22609606', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA28278924', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA34018049', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19569064', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA28297083', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA24559022', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA24541161', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA24249930', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19526657', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA6344841', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA16998583', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA28806871', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA24129500', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA27171262', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA15485875', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA17546621', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA14579609', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA23312246', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA15544119', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19800475', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA29588132', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18302793', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA23207394', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA29419766', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA44713076', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19149264', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18554605', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA15471004', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA39228411', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA24855152', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA23138487', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA12603131', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA28863724', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA32823373', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA15397548', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA27649309', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA21617548', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA15402448', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA22230323', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26057017', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA29000089', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA38921521', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19566649', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA35252219', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA41462284', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA23138486', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA44740757', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA20012261', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19826911', 'score': 1, 'status': 'shown'}]},
#  'user_context': None}

# %%
offsets = [i for i in range(0, 1000, 50)]

def fetch_category_data(country_id, category_id):
    serial_lst = []
    with requests.Session() as session:
        for offset in offsets:
            url = f"https://api.mercadolibre.com/sites/{country_id}/search?category={category_id}&offset={offset}"
            response = session.get(url)
            items = response.json()
            serial_lst.append(pd.DataFrame(items['results']))
    return pd.concat(serial_lst, ignore_index=True)


def process_country(country):
    cats = requests.get(f"https://api.mercadolibre.com/sites/{country['id']}/categories")
    category_ids_country = {item['id'] for item in cats.json()}
    
    with ThreadPoolExecutor() as executor:
            dataframes = list(executor.map(lambda category_id: fetch_category_data(country['id'], category_id), category_ids_country))
    
    df_country_id = pd.concat(dataframes, ignore_index=True)
    return df_country_id

# %%
lst = []

for i in range(len(country_info['country'])):
    country = country_info['country'][i]
    df = process_country(country)
    lst.append(df)
    print(f"{country['id']}: {df.shape}")
# Out:
# MEC: (25623, 40)
# MRD: (10853, 39)
# MLA: (31733, 40)
# MCO: (30874, 40)
# MBO: (2906, 39)
# MCR: (14823, 39)
# MLU: (30480, 40)
# MLB: (31695, 40)
# MPY: (6425, 39)
# MGT: (4819, 39)
# MSV: (844, 39)
# MPE: (29916, 40)
# MLM: (30521, 40)
# MHN: (1029, 39)
# MLV: (28482, 40)
# MNI: (726, 39)
# MPA: (3375, 39)

# %%
df = pd.concat(lst, ignore_index=True)

# %%
df.head()
# Out:
#              id                                              title condition  \
# 0  MEC565864602  Carolina Herrera Good Girl Tradicional Edp 80 ...       new
# 1  MEC556439976  Masajeador Facial Barra T Dorada Antiarrugas R...       new
# 2  MEC530948501  Maquina Afeitadora Trimmer Recargable Dorada D...       new
# 3  MEC565968568  Carolina Herrera 212 Heroes Forever Young Hero...       new
# 4  MEC592307172      144 Condones Preservativos Sure Uso Frecuente       new
#
#                    thumbnail_id catalog_product_id listing_type_id  \
# 0  920992-MLA49695549958_042022         MEC6271502        gold_pro
# 1  961391-MLU70396741248_072023        MEC24435970          bronze
# 2  605769-MLA79551245073_092024        MEC27999971        gold_pro
# 3  777985-MLA52221299620_102022        MEC19034511        gold_pro
# 4  912232-MLA80948355299_112024        MEC43769140          bronze
#
#   sanitized_title                                          permalink  \
# 0                  https://www.mercadolibre.com.ec/carolina-herre...
# 1                  https://www.mercadolibre.com.ec/masajeador-fac...
# 2                  https://www.mercadolibre.com.ec/maquina-afeita...
# 3                  https://www.mercadolibre.com.ec/carolina-herre...
# 4                  https://www.mercadolibre.com.ec/144-condones-p...
#
#   buying_mode site_id  ... discounts promotion_decorations promotions  \
# 0  buy_it_now     MEC  ...      None                  None       None
# 1  buy_it_now     MEC  ...      None                  None       None
# 2  buy_it_now     MEC  ...      None                  None       None
# 3  buy_it_now     MEC  ...      None                  None       None
# 4  buy_it_now     MEC  ...      None                  None       None
#
#   inventory_id  variation_id variations_data official_store_name  \
# 0         None           NaN             NaN                 NaN
# 1         None           NaN             NaN                 NaN
# 2         None           NaN             NaN                 NaN
# 3         None           NaN             NaN                 NaN
# 4         None           NaN             NaN                 NaN
#
#   variation_filters  location seller_contact
# 0               NaN       NaN            NaN
# 1               NaN       NaN            NaN
# 2               NaN       NaN            NaN
# 3               NaN       NaN            NaN
# 4               NaN       NaN            NaN
#
# [5 rows x 40 columns]
